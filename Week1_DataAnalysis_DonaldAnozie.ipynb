# %% [markdown]
# <a href="https://colab.research.google.com/github/Articrest/Active-Directory-Monitoring-Projects/blob/main/Week1_DataAnalysis_DonaldAnozie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===== WEEK 1 DATA ANALYSIS ASSIGNMENT =====
# Student: DONALD ANOZIE -DA
# Date: 07-08-2025
# Platform: Google Colab on Windows 11

print("Starting Week 1 Assignment...")

# Import the tools we need for data analysis
import pandas as pd          # For working with data tables
import numpy as np           # For math calculations
import matplotlib.pyplot as plt  # For creating charts
import seaborn as sns        # For making pretty charts

# Settings to make our charts look good
plt.style.use('default')
# %matplotlib inline

print("✅ Success! All tools are ready to use")
print("💻 Running on Windows 11 with Google Colab")
# Out:
# Starting Week 1 Assignment...
# ✅ Success! All tools are ready to use
# 💻 Running on Windows 11 with Google Colab

# %%
# Load our dataset - we'll use Titanic passenger data
# This data contains information about people who were on the Titanic ship
print("Loading dataset...")

df = sns.load_dataset('titanic')  # 'df' stands for 'dataframe' - it's like an Excel spreadsheet
dataset_name = "Titanic Passenger Data"

print(f"✅ Dataset loaded successfully!")
print(f"📊 Dataset name: {dataset_name}")
print(f"📏 Size: {df.shape[0]} rows (passengers) × {df.shape[1]} columns (information about each passenger)")
print(f"💾 Data size: {df.memory_usage(deep=True).sum() / 1024:.1f} KB")
print()
print("The columns (types of information) we have:")
print(list(df.columns))
# Out:
# Loading dataset...
# ✅ Dataset loaded successfully!
# 📊 Dataset name: Titanic Passenger Data
# 📏 Size: 891 rows (passengers) × 15 columns (information about each passenger)
# 💾 Data size: 313.7 KB
#
# The columns (types of information) we have:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
# ====== ASSIGNMENT REQUIREMENT 1: DATASET PREVIEW ======
# We need to show the first few rows of our data using .head()

print("🔍 DATASET PREVIEW - SHOWING FIRST 5 ROWS")
print("=" * 60)
print()

print(f"📋 Dataset: {dataset_name}")
print(f"📊 Total size: {df.shape[0]} passengers, {df.shape[1]} pieces of information per passenger")
print()

print("👀 Here are the first 5 passengers using .head():")
print("(This is like looking at the first 5 rows of an Excel spreadsheet)")
print()
df.head()  # This shows the first 5 rows
# Out:
# 🔍 DATASET PREVIEW - SHOWING FIRST 5 ROWS
# ...
#
# 📋 Dataset: Titanic Passenger Data
# 📊 Total size: 891 passengers, 15 pieces of information per passenger
#
# 👀 Here are the first 5 passengers using .head():
# (This is like looking at the first 5 rows of an Excel spreadsheet)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
# ====== ASSIGNMENT REQUIREMENT 2: SUMMARY STATISTICS ======
# We need to show statistical summary using .describe()

print("📊 SUMMARY STATISTICS - MATHEMATICAL SUMMARY OF OUR DATA")
print("=" * 60)
print()

print("🔢 Statistical summary of numerical columns using .describe():")
print("(This shows averages, minimums, maximums, etc.)")
print()
df.describe()  # This creates a statistical summary
# Out:
# 📊 SUMMARY STATISTICS - MATHEMATICAL SUMMARY OF OUR DATA
# ...
#
# 🔢 Statistical summary of numerical columns using .describe():
# (This shows averages, minimums, maximums, etc.)
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# ====== ASSIGNMENT REQUIREMENT 3: DATA VISUALIZATION ======
# We need to create at least 1 chart. We'll create 4 different charts!

print("📈 DATA VISUALIZATIONS - CREATING CHARTS FROM OUR DATA")
print("=" * 60)
print()

# Set up our chart area (like preparing a canvas for painting)
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Titanic Dataset Analysis - 4 Different Views of Our Data', fontsize=16, fontweight='bold')

# Chart 1: How many people survived vs died (Bar Chart)
survival_counts = df['survived'].value_counts()
axes[0, 0].bar(['Died', 'Survived'], survival_counts.values,
               color=['red', 'green'], alpha=0.7)
axes[0, 0].set_title('1. Survival Count: How Many Lived vs Died')
axes[0, 0].set_ylabel('Number of People')
axes[0, 0].grid(True, alpha=0.3)

# Chart 2: Age distribution (Histogram)
ages = df['age'].dropna()  # Remove missing ages
axes[0, 1].hist(ages, bins=20, color='skyblue', alpha=0.7, edgecolor='black')
axes[0, 1].set_title('2. Age Distribution: How Old Were Passengers')
axes[0, 1].set_xlabel('Age (years)')
axes[0, 1].set_ylabel('Number of People')
axes[0, 1].grid(True, alpha=0.3)

# Chart 3: Passenger class distribution (Bar Chart)
class_counts = df['class'].value_counts()
axes[1, 0].bar(class_counts.index, class_counts.values,
               color=['gold', 'silver', '#CD7F32'], alpha=0.7)
axes[1, 0].set_title('3. Ticket Class: First, Second, or Third Class')
axes[1, 0].set_xlabel('Class (1st=Expensive, 3rd=Cheap)')
axes[1, 0].set_ylabel('Number of People')
axes[1, 0].grid(True, alpha=0.3)

# Chart 4: Ticket prices (Box Plot)
fares = df['fare'].dropna()  # Remove missing fares
box_plot = axes[1, 1].boxplot(fares, patch_artist=True)
box_plot['boxes'][0].set_facecolor('lightcoral')
box_plot['boxes'][0].set_alpha(0.7)
axes[1, 1].set_title('4. Ticket Prices: How Much Did People Pay')
axes[1, 1].set_ylabel('Price ($)')
axes[1, 1].grid(True, alpha=0.3)

# Show all our charts
plt.tight_layout()
plt.show()

print("✅ All 4 visualizations created successfully!")
print("📊 Charts show: survival rates, age distribution, passenger classes, and ticket prices")
# Out:
# 📈 DATA VISUALIZATIONS - CREATING CHARTS FROM OUR DATA
# ...
# ✅ All 4 visualizations created successfully!
# 📊 Charts show: survival rates, age distribution, passenger classes, and ticket prices

# %% [markdown]
# # 📝 MY DATA ANALYSIS REPORT
#
# ## 📊 What Dataset Did I Analyze?
# I analyzed the **Titanic Passenger Data**, which contains information about 891 passengers who were on the famous Titanic ship that sank in 1912.
#
# ## 🔍 What Did I Discover?
#
# ### From the Dataset Preview (.head()):
# - I can see information about individual passengers
# - Each row represents one person
# - We have details like their age, ticket class, fare paid, and whether they survived
#
# ### From the Summary Statistics (.describe()):
# - **Average age**: About 30 years old
# - **Youngest passenger**: Less than 1 year old (a baby!)
# - **Oldest passenger**: 80 years old
# - **Average ticket price**: About $32
# - **Most expensive ticket**: Over $500!
#
# ### From My Charts:
# 1. **Survival Chart**: Sadly, more people died than survived
# 2. **Age Chart**: Most passengers were young adults (20-40 years old)
# 3. **Class Chart**: Most people had cheap tickets (3rd class)
# 4. **Price Chart**: Ticket prices varied wildly - some very expensive, some cheap
#
# ## 🎯 My Conclusions
# 1. The Titanic had passengers of all ages, from babies to elderly people
# 2. Most passengers couldn't afford expensive tickets
# 3. This tragic event affected many families
# 4. The data helps us understand who was on the ship that night
#
# ## 💻 How I Did This Analysis
# - **Platform**: Google Colab on my Windows 11 laptop
# - **Tools Used**: Python with pandas (data), matplotlib (charts), seaborn (pretty charts)
# - **Assignment Requirements**: ✅ Used .head(), ✅ Used .describe(), ✅ Created visualizations
